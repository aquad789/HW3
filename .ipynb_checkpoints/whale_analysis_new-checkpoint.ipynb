# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path
import requests

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns

# Set the file paths for the CSVs using the Path class from the pathlib library
whale_returns_path = Path("whale_returns.csv")
algo_returns_path = Path("algo_returns.csv")
sp500_history_path = Path("sp500_history.csv")

# %%
# Read the daily closing prices of MSFT, set the `date` as a datetime index
whale_returns = pd.read_csv(whale_returns_path, index_col='Date', infer_datetime_format=True, parse_dates=True)
algo_returns = pd.read_csv(algo_returns_path, index_col='Date', infer_datetime_format=True, parse_dates=True)
sp500_history  = pd.read_csv(sp500_history_path, index_col='Date', infer_datetime_format=True, parse_dates=True)

# %%
# Count nulls
whale_null = whale_returns.isnull().values.sum()
algo_null = algo_returns.isnull().values.sum()
sp500_null = sp500_history.isnull().values.sum()

print(f"Nulls -> whale returns: {whale_null}, algo returns:  {algo_null}, sp500: {sp500_null}")
# Out:
# Nulls -> whale returns: 4, algo returns:  6, sp500: 0

# %%
# Drop nulls
whale_returns = whale_returns.dropna()
algo_returns = algo_returns.dropna()
sp500_history = sp500_history.dropna()

#Test
#whale_null_v2 = whale_returns_xN.isnull().values.sum()
#whale_null_v2

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
# See above

# %%
# Count nulls
# See above

# %%
# Drop nulls
# See above

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history  = pd.read_csv(sp500_history_path, index_col='Date', infer_datetime_format=True, parse_dates=True)

# %%
sp500_history.head(5)
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_history['Close'] = sp500_history['Close'].str.replace('$',"")
sp500_history.head(5)
# Out:
# /var/folders/60/2vhxcr316gg1jg4wj6zc9nrm0000gn/T/ipykernel_854/3360640204.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_history['Close'] = sp500_history['Close'].str.replace('$',"")
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history['Close']=sp500_history['Close'].astype('float')

# %%
sp500_history.sort_index(inplace=True)
sp500_history.head(5)
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculate Daily Returns

sp500_returns = sp500_history.pct_change()

# %%
# Drop nulls
sp500_returns.dropna(inplace=True)
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns.rename(columns={'Close':'SP500_Close'}, inplace=True)
sp500_returns.head(5)
# Out:
#             SP500_Close
# Date
# 2012-10-02     0.000872
# 2012-10-03     0.003624
# 2012-10-04     0.007174
# 2012-10-05    -0.000322
# 2012-10-08    -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_daily_returns = pd.concat([whale_returns, algo_returns, sp500_returns], axis="columns", join="inner")
combined_daily_returns.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP500_Close
# Date
# 2015-03-03 -0.000949    -0.004539
# 2015-03-04  0.002416    -0.004389
# 2015-03-05  0.004323     0.001196
# 2015-03-06 -0.011460    -0.014174
# 2015-03-09  0.001303     0.003944

# %%
combined_daily_returns.tail(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2  SP500_Close
# Date
# 2019-04-16  0.002899     0.000509
# 2019-04-17 -0.005228    -0.002274
# 2019-04-18 -0.001229     0.001579
# 2019-04-22 -0.001936     0.001012
# 2019-04-23  0.009622     0.008841

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_daily_returns.plot(title = "Daily Returns", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
combined_cum_return = (1+combined_daily_returns).cumprod()-1
# Plot cumulative returns
combined_cum_return.plot(title = "Cumulative Returns", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_daily_returns.plot(kind='box', legend =True, title = "Daily Returns - Box Plot", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Daily Returns - Box Plot'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_stdev = combined_daily_returns.std()
daily_stdev_df = pd.DataFrame(daily_stdev)
#print(daily_stdev[1])
daily_stdev.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# SP500_Close                    0.008554
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
SP500_stdev = combined_daily_returns['SP500_Close'].std()

# Determine which portfolios are riskier than the S&P 500
for index in daily_stdev_df[0]:
    if (index > SP500_stdev):
           print(index)
# Out:
# 0.010893969618743005
# 0.012918618441883491

# %%
#print(daily_stdev_df[])

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_stdev = daily_stdev*np.sqrt(252)
annualized_stdev
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# SP500_Close                    0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_rolling_std = combined_daily_returns.rolling(window=21).std()

# Plot the rolling standard deviation
combined_rolling_std.plot(figsize=(20, 10), title='Rolling 21-Day STDEV of all portfolios')
# Out:
# <AxesSubplot:title={'center':'Rolling 21-Day STDEV of all portfolios'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation_matrix = combined_daily_returns.corr()

# Display de correlation matrix
correlation_matrix
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# SP500_Close                                   0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# Algo 2                                          0.507414
# SP500_Close                                     0.623946
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754360  0.321211  0.826873
# PAULSON & CO.INC.                          0.545623  0.268840  0.678152
# TIGER GLOBAL MANAGEMENT LLC                0.424423  0.164387  0.507414
# BERKSHIRE HATHAWAY INC                     1.000000  0.292033  0.688082
# Algo 1                                     0.292033  1.000000  0.288243
# Algo 2                                     0.688082  0.288243  1.000000
# SP500_Close                                0.751371  0.279494  0.858764
#
#                              SP500_Close
# SOROS FUND MANAGEMENT LLC       0.837864
# PAULSON & CO.INC.               0.669732
# TIGER GLOBAL MANAGEMENT LLC     0.623946
# BERKSHIRE HATHAWAY INC          0.751371
# Algo 1                          0.279494
# Algo 2                          0.858764
# SP500_Close                     1.000000

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
rolling_bhi_covariance = combined_daily_returns['BERKSHIRE HATHAWAY INC'].rolling(window=21).cov(combined_daily_returns['SP500_Close'])

# Calculate variance of S&P 500
rolling_sp500_variance = combined_daily_returns['SP500_Close'].rolling(window=21).var()

# Computing beta
rolling_bhi_beta = rolling_bhi_covariance / rolling_sp500_variance

# Plot beta trend
rolling_bhi_beta.plot(figsize=(20, 10), title='Berkshire Hathaway Inc Rolling Beta Trend')
# Out:
# <AxesSubplot:title={'center':'Berkshire Hathaway Inc Rolling Beta Trend'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
rolling_ewm_bhi_covariance = combined_daily_returns['BERKSHIRE HATHAWAY INC'].ewm(halflife=90).cov(combined_daily_returns['SP500_Close'])
rolling_ewm_sp500_variance = combined_daily_returns['SP500_Close'].ewm(halflife=90).var()
rolling_ewm_bhi_beta = rolling_ewm_bhi_covariance / rolling_ewm_sp500_variance

rolling_ewm_bhi_beta.plot(figsize=(20, 10), title='Berkshire Hathaway Inc EWM Beta Trend')
# Out:
# <AxesSubplot:title={'center':'Berkshire Hathaway Inc EWM Beta Trend'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
combined_portfolio_sharpe = ((combined_daily_returns - 0)/ annualized_stdev)

# %%
# Visualize the sharpe ratios as a bar plot
combined_portfolio_sharpe.plot(figsize=(20, 10), kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %%
combined_portfolio_sharpe.mean()
print('#######   Algo 1 outperforms both   ########')
# Out:
# #######   Algo 1 outperforms both   ########

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
apple_history_path = Path("aapl_historical.csv")
apple_history = pd.read_csv(apple_history_path, index_col='Trade DATE', infer_datetime_format=True, parse_dates=True)
apple_history.rename(columns={'NOCP':'Apple'},inplace=True)
apple_history.drop(columns=['Symbol'],inplace=True)
apple_history.head(5)
# Out:
#              Apple
# Trade DATE
# 2019-05-09  200.72
# 2019-05-08  202.90
# 2019-05-07  202.86
# 2019-05-06  208.48
# 2019-05-03  211.75

# %%
# Reading data from 2nd stock
google_history_path = Path("goog_historical.csv")
google_history = pd.read_csv(google_history_path, index_col='Trade DATE', infer_datetime_format=True, parse_dates=True)
google_history.rename(columns={'NOCP':'Google'},inplace=True)
google_history.drop(columns=['Symbol'],inplace=True)
google_history.head(5)
# Out:
#              Google
# Trade DATE
# 2019-05-09  1162.38
# 2019-05-08  1166.27
# 2019-05-07  1174.10
# 2019-05-06  1189.39
# 2019-05-03  1185.40

# %%
# Reading data from 3rd stock
costco_history_path = Path("cost_historical.csv")
costco_history = pd.read_csv(costco_history_path, index_col='Trade DATE', infer_datetime_format=True, parse_dates=True)
costco_history.rename(columns={'NOCP':'Costco'},inplace=True)
costco_history.drop(columns=['Symbol'],inplace=True)
costco_history.head(5)
# Out:
#             Costco
# Trade DATE
# 2019-05-09  243.47
# 2019-05-08  241.34
# 2019-05-07  240.18
# 2019-05-06  244.23
# 2019-05-03  244.62

# %%
# Combine all stocks in a single DataFrame
mystocks_history = pd.concat([apple_history, google_history, costco_history], axis="columns", join="inner")
mystocks_history.head(5)
# Out:
#              Apple   Google  Costco
# Trade DATE
# 2019-05-09  200.72  1162.38  243.47
# 2019-05-08  202.90  1166.27  241.34
# 2019-05-07  202.86  1174.10  240.18
# 2019-05-06  208.48  1189.39  244.23
# 2019-05-03  211.75  1185.40  244.62

# %%
# Reset Date index
mystocks_history.sort_index(inplace=True)
mystocks_history.head(5)
# Out:
#              Apple   Google  Costco
# Trade DATE
# 2018-05-11  188.59  1098.26  195.76
# 2018-05-14  188.15  1100.20  195.88
# 2018-05-15  186.44  1079.23  195.48
# 2018-05-16  188.18  1081.77  198.71
# 2018-05-17  186.99  1078.59  199.60

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns
mystocks_daily_returns = mystocks_history.pct_change().dropna()
#Drop NAs

# Display sample data
mystocks_daily_returns.sort_index(inplace=True)
mystocks_daily_returns.head(5)
# Out:
#                Apple    Google    Costco
# Trade DATE
# 2018-05-14 -0.002333  0.001766  0.000613
# 2018-05-15 -0.009088 -0.019060 -0.002042
# 2018-05-16  0.009333  0.002354  0.016523
# 2018-05-17 -0.006324 -0.002940  0.004479
# 2018-05-18 -0.003637 -0.011339 -0.003206

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
myportfolio_daily_returns = mystocks_daily_returns.dot(weights)
myportfolio_daily_returns_new =  myportfolio_daily_returns.dropna()
myportfolio_daily_returns_new.columns = ['MyPortfolio']
myportfolio_daily_returns_new.sort_index(inplace=True)


# Display sample data
myportfolio_daily_returns_new.head(5)
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_combined_daily_returns = pd.concat([combined_daily_returns, myportfolio_daily_returns_new], axis="columns", join="inner")
all_combined_daily_returns.columns = ['Soros', 'Paulson','Tiger', 'Berkshire Hathaway', 'Algo 1', 'Algo2', 'SP500', 'MyPortfolio']
all_combined_daily_returns.head(5)
# Out:
#                Soros   Paulson     Tiger  Berkshire Hathaway    Algo 1  \
# 2018-05-14  0.000000  0.000000  0.000000            0.000000  0.000915
# 2018-05-15 -0.000726 -0.001409 -0.003189           -0.014606 -0.001135
# 2018-05-16  0.008637  0.006244  0.005480            0.004310 -0.002326
# 2018-05-17 -0.001955  0.002524 -0.006267           -0.005140 -0.006949
# 2018-05-18 -0.004357 -0.002672 -0.012832           -0.002212  0.002557
#
#                Algo2     SP500  MyPortfolio
# 2018-05-14  0.001635  0.000884     0.000015
# 2018-05-15 -0.001139 -0.006842    -0.010064
# 2018-05-16  0.003341  0.004061     0.009403
# 2018-05-17  0.005205 -0.000856    -0.001595
# 2018-05-18 -0.002496 -0.002632    -0.006061

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_combined_daily_returns.dropna(inplace=True)
all_combined_daily_returns.head(5)
# Out:
#                Soros   Paulson     Tiger  Berkshire Hathaway    Algo 1  \
# 2018-05-14  0.000000  0.000000  0.000000            0.000000  0.000915
# 2018-05-15 -0.000726 -0.001409 -0.003189           -0.014606 -0.001135
# 2018-05-16  0.008637  0.006244  0.005480            0.004310 -0.002326
# 2018-05-17 -0.001955  0.002524 -0.006267           -0.005140 -0.006949
# 2018-05-18 -0.004357 -0.002672 -0.012832           -0.002212  0.002557
#
#                Algo2     SP500  MyPortfolio
# 2018-05-14  0.001635  0.000884     0.000015
# 2018-05-15 -0.001139 -0.006842    -0.010064
# 2018-05-16  0.003341  0.004061     0.009403
# 2018-05-17  0.005205 -0.000856    -0.001595
# 2018-05-18 -0.002496 -0.002632    -0.006061

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
all_combined_std = all_combined_daily_returns.std()*np.sqrt(252)
all_combined_std.head(5)
# Out:
# Soros                 0.146675
# Paulson               0.116732
# Tiger                 0.232531
# Berkshire Hathaway    0.247155
# Algo 1                0.133704
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
all_combined_rolling_std = all_combined_daily_returns.rolling(window=21).std()

# Plot rolling standard deviation

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
all_combined_rolling_std = all_combined_daily_returns.rolling(window=21).std()

# Plot the rolling standard deviation
all_combined_rolling_std.plot(figsize=(20, 10), title='Rolling 21-Day STDEV of all combined portfolios')
# Out:
# <AxesSubplot:title={'center':'Rolling 21-Day STDEV of all combined portfolios'}>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
all_combined_correlation_matrix = all_combined_daily_returns.corr()
all_combined_correlation_matrix
# Out:
#                        Soros   Paulson     Tiger  Berkshire Hathaway  \
# Soros               1.000000  0.791962  0.478627            0.816675
# Paulson             0.791962  1.000000  0.485375            0.650758
# Tiger               0.478627  0.485375  1.000000            0.325457
# Berkshire Hathaway  0.816675  0.650758  0.325457            1.000000
# Algo 1              0.337826  0.361301  0.114554            0.327000
# Algo2               0.862846  0.783656  0.409496            0.782804
# SP500               0.876981  0.766680  0.481030            0.852303
# MyPortfolio         0.733250  0.644210  0.391972            0.801158
#
#                       Algo 1     Algo2     SP500  MyPortfolio
# Soros               0.337826  0.862846  0.876981     0.733250
# Paulson             0.361301  0.783656  0.766680     0.644210
# Tiger               0.114554  0.409496  0.481030     0.391972
# Berkshire Hathaway  0.327000  0.782804  0.852303     0.801158
# Algo 1              1.000000  0.365512  0.289358     0.261471
# Algo2               0.365512  1.000000  0.875721     0.739936
# SP500               0.289358  0.875721  1.000000     0.871875
# MyPortfolio         0.261471  0.739936  0.871875     1.000000

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

# %%
# Calculate covariance of a single portfolio
rolling_my_portfolio_covariance = all_combined_daily_returns['MyPortfolio'].rolling(window=21).cov(all_combined_daily_returns['SP500'])

# Calculate variance of S&P 500
rolling_sp500_variance = all_combined_daily_returns['SP500'].rolling(window=21).var()

# Computing beta
rolling_my_portfolio_beta = rolling_my_portfolio_covariance / rolling_sp500_variance

# Plot beta trend
rolling_my_portfolio_beta.plot(figsize=(20, 10), title='MyPortfolio Rolling Beta Trend', ylabel='Rolling Beta')
# Out:
# <AxesSubplot:title={'center':'MyPortfolio Rolling Beta Trend'}, ylabel='Rolling Beta'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios

# %%
# Annualized Sharpe Ratios
my_portfolio_sharpe = ((all_combined_daily_returns['MyPortfolio'] - 0)/ all_combined_std['SP500'])
my_portfolio_sharpe.head(5)
# Out:
# 2018-05-14    0.000102
# 2018-05-15   -0.066184
# 2018-05-16    0.061841
# 2018-05-17   -0.010489
# 2018-05-18   -0.039858
# Name: MyPortfolio, dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
my_portfolio_sharpe.mean()
# Out:
# 0.005150409336754902

# %%
# Visualize the sharpe ratios as a bar plot
my_portfolio_sharpe.plot(figsize=(20, 10), kind='bar', title='MyPortfolio Sharpe')
# Out:
# <AxesSubplot:title={'center':'MyPortfolio Sharpe'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
print('MyPortfolio is the 2nd best performer of the entire group on a Sharpe Ratio criteria basis, right after Algo 1')
# Out:
# MyPortfolio is the 2nd best performer of the entire group on a Sharpe Ratio criteria basis, right after Algo 1
